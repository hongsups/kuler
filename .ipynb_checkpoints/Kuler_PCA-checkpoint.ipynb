# %% [markdown]
# #Kuler: PCA/kmeans

# %% [markdown]
# ##Import modules

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import scipy as sp

# plotting
import seaborn as sns
sns.set(style="whitegrid")
import matplotlib.pyplot as plt
import matplotlib.cm as pltcm
# %matplotlib inline

# %% [markdown]
# ##load dataframes and ndarrays

# %%
df_ = pd.read_pickle('kuler_df_')
df_all = pd.read_pickle('kuler_df_all')
data_pair = np.load('kuler_data_pair.npy')
data_LabAll = np.load('kuler_data_LabAll.npy')

# %% [markdown]
# ##I. run PCA and create a 2D/3D plot (raw data)

# %%
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
def PCA_test(X,N,index1=0,index2=0):
    # viewpoint
    if index1 == 'a' and index2 == 'b':
        el = 90
        az = -90
    elif index1 == 'L' and index2 == 'a':
        el = 0
        az = 90
    elif index1 == 'L' and index2 == 'b':
        el = 0
        az = 180
    elif int(index1) == 0 and int(index2) == 0:
        el = None
        az = None
        
    pca = PCA(n_components=N)
    pca.fit(X)
    PCA(copy=True, n_components=3, whiten=False)
    print(pca.explained_variance_ratio_) 
    print(pca.score(X))
    Y = pca.transform(X)

    fig = plt.figure(1, figsize=(7, 7))
    if N == 3:
        ax = Axes3D(fig)
        ax.view_init(elev=el,azim=az)
        ax.scatter(Y[:, 0], Y[:, 1], Y[:, 2],alpha=0.2)
    elif N == 2:
        plt.scatter(Y[:, 0], Y[:, 1],alpha=0.2)

# %%
PCA_test(data_pair,2)
# Out:
# [ 0.28229556  0.18941837]
# -42.0792082719

# %%
PCA_test(data_pair,3)
# Out:
# [ 0.28229556  0.18941837  0.14331591]
# -41.8263432149

# %%
PCA_test(data_LabAll,2)
# Out:
# [ 0.18359344  0.16506958]
# -69.7138816304

# %%
PCA_test(data_LabAll,3)
# Out:
# [ 0.18359344  0.16506958  0.12687431]
# -69.3587801343

# %% [markdown]
# ##II. PCA with coordinate vectors after feature scaling

# %% [markdown]
# ##Attempt 1: Standardizing

# %%
df_.head()
# Out:
#                                                 Lab1  \
# 0  LabColor (lab_l:89.0695 lab_a:-6.6474 lab_b:25...
# 1  LabColor (lab_l:52.0084 lab_a:-29.9085 lab_b:1...
# 2  LabColor (lab_l:99.5372 lab_a:-2.7206 lab_b:4....
# 3  LabColor (lab_l:61.7404 lab_a:58.1302 lab_b:53...
# 4  LabColor (lab_l:34.9884 lab_a:-18.4360 lab_b:-...
#
#                                                 Lab2  \
# 0  LabColor (lab_l:66.4561 lab_a:-4.7082 lab_b:19...
# 1  LabColor (lab_l:94.4397 lab_a:-5.5449 lab_b:38...
# 2  LabColor (lab_l:85.9526 lab_a:-8.6124 lab_b:13...
# 3  LabColor (lab_l:98.1196 lab_a:-13.8177 lab_b:4...
# 4  LabColor (lab_l:97.8074 lab_a:-4.2721 lab_b:18...
#
#                                                 Lab3  \
# 0  LabColor (lab_l:92.8418 lab_a:-4.5533 lab_b:16...
# 1  LabColor (lab_l:77.6561 lab_a:19.3233 lab_b:67...
# 2  LabColor (lab_l:67.4290 lab_a:-11.2795 lab_b:3...
# 3  LabColor (lab_l:88.3837 lab_a:-27.7910 lab_b:3...
# ...

# %%
# Ignore the LabColor columns
df_coord = df_.loc[:,df_.columns[5:]]

# %%
# standardizing
df_coord_stnd = (df_coord - df_coord.mean())/df_coord.std()
df_coord_stnd.head()
# Out:
#          L1        a1        b1        L2        a2        b2        L3  \
# 0  1.544107 -0.460522  0.554048  0.345563 -0.227481  0.160654  1.196912
# 1  0.204391 -1.315397  0.074245  1.504793 -0.259360  0.799610  0.514942
# 2  1.922505 -0.316204 -0.213499  1.153211 -0.376236 -0.054768  0.055655
# 3  0.556190  1.920142  1.573371  1.657233 -0.574564  1.102511  0.996704
# 4 -0.410864 -0.893767 -0.770075  1.644300 -0.210864  0.110949  0.898939
#
#          a3        b3        L4        a4        b4        L5        a5  \
# 0 -0.221264 -0.077188 -1.029836 -0.655361 -1.505872 -1.441609 -0.828630
# 1  0.714501  1.690736 -0.744728  1.441142  0.781908 -0.863137  1.083937
# 2 -0.484874 -0.532945 -1.027623 -0.458308 -1.132311 -1.311752 -0.526753
# 3 -1.131988  0.459863  0.351759 -1.345917 -0.114468  0.146717 -1.769159
# 4  0.036208  1.727957  0.272532  0.349309  1.416545 -0.336298  1.214196
#
#          b5
# 0 -0.795637
# 1  0.951530
# 2 -1.043073
# 3 -0.500879
# 4  0.690874

# %%
# check if the standardization worked
print df_coord_stnd.mean()
print df_coord_stnd.std()
# Out:
# L1   -3.239032e-15
# a1    5.332999e-16
# b1   -1.241441e-15
# L2   -6.221617e-16
# a2   -3.633386e-17
# b2   -1.334874e-15
# L3   -1.512605e-14
# a3    5.977778e-17
# b3    3.503045e-15
# L4   -1.604116e-15
# a4   -2.742348e-16
# b4   -6.332954e-16
# L5    8.295433e-15
# a5    1.009665e-15
# b5   -1.269405e-16
# dtype: float64
# L1    1
# a1    1
# b1    1
# L2    1
# a2    1
# b2    1
# L3    1
# a3    1
# b3    1
# L4    1
# a4    1
# b4    1
# L5    1
# a5    1
# b5    1
# dtype: float64

# %%
# First 2 components
PCA_test(df_coord_stnd,2)
# Out:
# [ 0.18255133  0.15472604]
# -20.4632592514

# %%
# 3 components
PCA_test(df_coord_stnd,3)
# Out:
# [ 0.18255133  0.15472604  0.12799735]
# -20.1161961304

# %%
# Visualize explained variance ratio
X = df_coord_stnd
N = 10
def plot_exp_var_ratio(X,N):
    """Create a bar plot of explained variance ratio of N components from the PCA results using data X"""
    pca = PCA(n_components=N)
    pca.fit(X)
    PCA(copy=True, n_components=3, whiten=False)
    print 'var: ' + str((pca.explained_variance_ratio_)) 
    print 'score: '+str((pca.score(X)))
    Y = pca.transform(X)
    plt.bar(range(N),pca.explained_variance_ratio_)
    plt.xticks(np.array(range(N))+0.4,range(1,N+1))
    plt.ylabel('Explained Var Ratio')
    plt.xlabel('pc #')
    plt.show()
    return Y
plot_exp_var_ratio(X,N)
# Out:
# var: [ 0.18255133  0.15472604  0.12799735  0.11929115  0.07823813  0.06104002
#   0.05235984  0.04079025  0.03801644  0.03514944]
# score: -19.1176168129
# array([[-2.03299246, -0.80565902, -0.97850506, ..., -0.17356697,
#         -0.38287176,  0.80967547],
#        [-1.64162948,  3.06873361,  0.94997398, ..., -0.38408622,
#          0.54167156,  0.34033052],
#        [-1.9993211 , -0.87032787, -0.51347298, ..., -0.5827445 ,
#         -0.48952805,  0.68754399],
#        ...,
#        [ 0.91739291, -0.80337573,  1.3545556 , ...,  0.27284931,
#         -0.15377048,  0.15296199],
#        [-1.94669997, -0.88610173, -0.50212444, ..., -0.67312926,
#         -0.48625088,  0.68632885],
#        [ 1.5193234 ,  0.0546426 , -0.81941272, ..., -0.08860098,
#          0.19169956,  1.02820929]])

# %%
# Compare this with raw data
plot_exp_var_ratio(df_coord,10)
# Out:
# var: [ 0.18359344  0.16506958  0.12687431  0.11276597  0.07648041  0.06263665
#   0.04993546  0.04262535  0.03768833  0.03529311]
# score: -68.3812844889

# %% [markdown]
# ##Attempt 2: Change the range of L coordinates
# - L coordinate range: [0, 100] (arbitrary range)
# - Let's match the range of L to the range of A or B [-128,128]

# %%
# Pick L coordinates and match the range 
df_coord_range.loc[:,df_coord.columns[np.array(range(5))*3]] = (df_coord_range.loc[:,df_coord.columns[np.array(range(5))*3]]-50)*128/50

# %%
df_coord.std()
# Out:
# L1    27.663363
# a1    27.209923
# b1    27.453080
# L2    24.139805
# a2    26.245910
# b2    28.673466
# L3    22.267416
# a3    25.515631
# b3    28.686625
# L4    23.477782
# a4    26.462751
# b4    28.444059
# L5    27.180457
# a5    29.402092
# b5    28.104215
# dtype: float64

# %%
df_coord_range.describe()
# Out:
#                 L1           a1           b1           L2           a2  \
# count  4931.000000  4931.000000  4931.000000  4931.000000  4931.000000
# mean     -9.333021     5.883332    10.278128    20.772579     1.262279
# std      70.818209    27.209923    27.453080    61.797900    26.245910
# min    -128.000000   -81.292880   -98.362560  -128.000000   -86.182949
# 25%     -71.372257    -7.943605    -8.546758   -27.633781   -14.302672
# 50%     -16.579491    -0.000283     2.755488    26.454890    -1.820359
# 75%      48.395795    13.440261    26.730958    70.046869    11.311405
# max     127.999960    88.893344    94.098353   127.999960    93.259145
#
#                 b2           L3           a3           b3           L4  \
# count  4931.000000  4931.000000  4931.000000  4931.000000  4931.000000
# mean     15.185324    41.445624     1.092403    19.084862    33.064892
# std      28.673466    57.004585    25.515631    28.686625    60.103122
# ...

# %%
PCA_test(df_coord_range,2)
# Out:
# [ 0.37940314  0.23487268]
# -86.1988173822

# %%
PCA_test(df_coord_range,3)
# Out:
# [ 0.37940314  0.23487268  0.19165038]
# -83.4905192131

# %%
plot_exp_var_ratio(df_coord_range,10)
# Out:
# var: [ 0.37940314  0.23487268  0.19165038  0.08910574  0.05692169  0.01187262
#   0.01032744  0.00623536  0.00468917  0.00425263]
# score: -77.767107646

# %% [markdown]
# ##Conclusion
# - Explained variance ratio increasd for the "range" scaling. However, this can be due to the increase of variance in L coordinates.
# - Standardizing does not change explained variance ratio much because the raw data already had very similar variance.

# %% [markdown]
# ##III. Kmeans using principle components
# ##1. Unscaled data
